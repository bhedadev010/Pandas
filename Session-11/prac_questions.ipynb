# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. find total revenue generated

# %%
course = pd.read_csv('courses.csv')
course
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
n = pd.read_csv('reg-month1.csv')
d = pd.read_csv('reg-month2.csv')
new = pd.concat([n,d],ignore_index=True)
new
#std_id, course_id

# %%
a = pd.merge(course,new)
a
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499          23
# 1           1            python   2499          18
# 2           1            python   2499           1
# 3           1            python   2499          15
# 4           1            python   2499          21
# 5           1            python   2499          25
# 6           1            python   2499          12
# 7           1            python   2499          14
# 8           1            python   2499          38
# 9           2               sql   3499          19
# 10          2               sql   3499           7
# 11          3     data analysis   4999          22
# 12          3     data analysis   4999          13
# 13          3     data analysis   4999          23
# 14          3     data analysis   4999           3
# 15          3     data analysis   4999          16
# 16          4  machine learning   9999          23
# ...

# %%
a['price'].sum()
# Out:
# np.int64(154247)

# %% [markdown]
# 2. find month by month revenue

# %%
b = pd.merge(course,n)
b['price'].sum()
# Out:
# np.int64(89175)

# %%
b = pd.merge(course,d)
b['price'].sum()
# Out:
# np.int64(65072)

# %% [markdown]
# 3. Print the registration table(cols -> name -> course -> price

# %%
d = a[['student_id','course_name','price']]
d
# Out:
#     student_id       course_name  price
# 0           23            python   2499
# 1           18            python   2499
# 2            1            python   2499
# 3           15            python   2499
# 4           21            python   2499
# 5           25            python   2499
# 6           12            python   2499
# 7           14            python   2499
# 8           38            python   2499
# 9           19               sql   3499
# 10           7               sql   3499
# 11          22     data analysis   4999
# 12          13     data analysis   4999
# 13          23     data analysis   4999
# 14           3     data analysis   4999
# 15          16     data analysis   4999
# 16          23  machine learning   9999
# 17          19  machine learning   9999
# 18          24  machine learning   9999
# 19          14  machine learning   9999
# 20          15           tableau   2499
# 21          16           tableau   2499
# ...

# %% [markdown]
# 4. find students who enrolled in both the months

# %%
#doubt

a = pd.read_csv('reg-month1.csv')
b = pd.read_csv('reg-month2.csv')

a = pd.merge(a,b,how='inner', on='student_id')
a['student_id'].unique()
# Out:
# array([23, 18, 16,  1,  7, 22, 11, 17,  3])

# %% [markdown]
# 5. find course that got no enrollment

# %%
#doubt

e = pd.merge(course,new,on='course_id',how='outer')
e
# Out:
#     course_id       course_name  price  student_id
# 0           1            python   2499        23.0
# 1           1            python   2499        18.0
# 2           1            python   2499         1.0
# 3           1            python   2499        15.0
# 4           1            python   2499        21.0
# 5           1            python   2499        25.0
# 6           1            python   2499        12.0
# 7           1            python   2499        14.0
# 8           1            python   2499        38.0
# 9           2               sql   3499        19.0
# 10          2               sql   3499         7.0
# 11          3     data analysis   4999        22.0
# 12          3     data analysis   4999        13.0
# 13          3     data analysis   4999        23.0
# 14          3     data analysis   4999         3.0
# 15          3     data analysis   4999        16.0
# 16          4  machine learning   9999        23.0
# ...
