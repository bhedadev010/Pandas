# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('imdb-top-1000.csv')

## find the genre with highest avg IMDB rating

movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
# find director with most popularity

movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
# find the highest rated movie of each genre

highest_rated_per_genre = movies.loc[movies.groupby('Genre')['IMDB_Rating'].idxmax()]
print(highest_rated_per_genre[['Genre', 'Series_Title', 'IMDB_Rating']])
# Out:
#          Genre                     Series_Title  IMDB_Rating
# 2       Action                  The Dark Knight          9.0
# 21   Adventure                     Interstellar          8.6
# 23   Animation    Sen to Chihiro no kamikakushi          8.6
# 7    Biography                 Schindler's List          8.9
# 19      Comedy                     Gisaengchung          8.6
# 1        Crime                    The Godfather          9.2
# 0        Drama         The Shawshank Redemption          9.3
# 688     Family       E.T. the Extra-Terrestrial          7.8
# 321    Fantasy     Das Cabinet des Dr. Caligari          8.1
# 309  Film-Noir                    The Third Man          8.1
# 49      Horror                           Psycho          8.5
# 69     Mystery                          Memento          8.4
# 700   Thriller                  Wait Until Dark          7.8
# 12     Western  Il buono, il brutto, il cattivo          8.8

# %%
# find number of movies done by each actor

movies.groupby('Star1').size().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks               12
# Robert De Niro          11
# Clint Eastwood          10
# Al Pacino               10
# Humphrey Bogart          9
#                         ..
# Zbigniew Zamachowski     1
# Zooey Deschanel          1
# Çetin Tekindor           1
# Éric Toledano            1
# Aaron Taylor-Johnson     1
# Length: 660, dtype: int64

# %%
movies.groupby('Genre').nth(1)
# Out:
#                                       Series_Title Released_Year  Runtime  \
# 3                           The Godfather: Part II          1974      202
# 5    The Lord of the Rings: The Return of the King          2003      201
# 9                                       Fight Club          1999      139
# 15                                      Goodfellas          1990      146
# 26                                 La vita è bella          1997      116
# 43                                   The Lion King          1994       88
# 47                              Back to the Future          1985      116
# 48                    Once Upon a Time in the West          1968      165
# 75                                           Alien          1979      117
# 81                                     Rear Window          1954      112
# 456                             The Maltese Falcon          1941      100
# 568                                      Nosferatu          1922       94
# ...

# %%
#aggregate functions

movies.agg({
    'Runtime' : 'max',
    'Metascore' : 'sum'
})
# Out:
# Runtime        321.0
# Metascore    65730.0
# dtype: float64

# %%
movies.agg(['max','sum'])
# Out:
#                                           Series_Title  \
# max                        Ôkami kodomo no Ame to Yuki
# sum  The Shawshank RedemptionThe GodfatherThe Dark ...
#
#                                          Released_Year  Runtime  \
# max                                                 PG      321
# sum  1994197220081974195720031994199320101999200119...   122891
#
#                                                  Genre  IMDB_Rating  \
# max                                            Western          9.3
# sum  DramaCrimeActionCrimeCrimeActionCrimeBiography...       7949.3
#
#                                               Director  \
# max                                   Ömer Faruk Sorak
# sum  Frank DarabontFrancis Ford CoppolaChristopher ...
#
#                                                  Star1  No_of_Votes  \
# max                                   Ömer Faruk Sorak      2343110
# sum  Tim RobbinsMarlon BrandoChristian BaleAl Pacin...    273692911
#
# ...

# %%
movies.agg({
    'Runtime' : ['sum','max'],
    'Metascore' : ['mean','max']
})
# Out:
#        Runtime  Metascore
# sum   122891.0        NaN
# max      321.0  100.00000
# mean       NaN   77.97153

# %%
# new = pd.concat([a,b],ignore_index=True)
#will concat two table together and if ig_in is not used then the index will be in same order as it is in table
#but if  ig_in is used then index will be in one flow

# %%
# studetnts.merge(new, how="inner",on="student_id")
# left,right,inner join
# left,right,outer join

# %%
#pd.merge(d1,d2,how='')
#two syntax available
